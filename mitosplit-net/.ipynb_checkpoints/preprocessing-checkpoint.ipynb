# %% [markdown]
# # Data preprocessing

# %%
import plotting
import util
import preprocessing

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import Normalize
plt.rc('xtick', labelsize=18)
plt.rc('ytick', labelsize=18)

plt.rc('axes', labelsize=20)
plt.rc('legend', fontsize=18)
from tqdm import tqdm

from skimage import filters, segmentation, feature, measure, morphology
from skimage.exposure import equalize_adapthist, rescale_intensity
from skimage.color import label2rgb
from skimage.io import imread, imsave

import scipy.ndimage as ndi

# %% [markdown]
# ## Import input and output data

# %%
base_dir = 'H:/Santi/'
data_path = base_dir+'Data/' 

#Inputs
input_data = util.load_h5(data_path, 'Mito')
print('Inputs'+':', input_data.shape)

#Outputs
output_data = util.load_h5(data_path, 'Proc')
print('Outputs:', output_data.shape)
# Out:
# Loading H:/Santi/Data/Mito.h5
# Converting to array
# Inputs: (37000, 128, 128)
#
# Loading H:/Santi/Data/Proc.h5
# Converting to array
# Outputs: (37000, 128, 128)

# %% [markdown]
# ## Input data histogram equalization

# %%
#clip_limit = 0.1
#proc_input_data = np.array([equalize_adapthist(input_img, clip_limit=clip_limit) for input_img in tqdm(input_data, total=input_data.shape[0])])
#bg_max_intensity = proc_input_data[input_data==0].max()
#proc_input_data = (255*np.clip((proc_input_data-bg_max_intensity)/(proc_input_data.max()-bg_max_intensity), 0, 1)).astype(input_data.dtype)

proc_input_data = util.load_h5(data_path, 'MitoProc')
print('Equalized inputs:', proc_input_data.shape)

# %%
frame = 34136
plotting.plot_comparison(input_data[frame], proc_input_data[frame], cmap='viridis', labels=['input_data', 'proc_input_data'], frame=frame)
plt.show()

# %% [markdown]
# ## GT preprocessing
# ### Filter events by mean probability of division and replace each fission by a gaussian disk
# Original GT prepared by Dora Mahecic includes all of the events that might be fissions:

# %%
item_id = 3#34136#26286#np.random.randint(0, len(proc_output_data))
img = output_data[item_id]
cmap = 'jet'
title = 'ground_truth'
filename = base_dir+'Figures/'+title+'_t{:05}.pdf'.format(item_id)
print(filename)

fig, ax = plt.subplots(figsize=(5, 5))
ax.set_title(title.title(), size=20)
ax.imshow(img, cmap=cmap)
ax.axis('off')
plt.tight_layout(pad=0)
plt.show()
#plt.savefig(filename)
# Out:
# H:/Santi/Figures/ground_truth_t00003.pdf

# %% [markdown]
# To filter this GT:
#
# 1. Remove events that are in contact with the border of the image.
# 2. Calculate the Distance Map by measuring the distance from local maxima to the border of the object

# %%
sigma = 0.5
mask = segmentation.clear_border(img>0)
img_proc = img*mask
distance = ndi.distance_transform_edt(filters.gaussian(img_proc, sigma/10))

cmap = 'gray'
title = 'distance_map'
filename = base_dir+'Figures/'+title+'_t{:05}.pdf'.format(item_id)
print(filename)

fig, ax = plt.subplots(figsize=(5, 5))
ax.set_title(title.title(), size=20)
ax.imshow(distance, cmap=cmap)
ax.axis('off')
plt.tight_layout(pad=0)
plt.show()
#plt.savefig(filename)
# Out:
# H:/Santi/Figures/distance_map_t00003.pdf

# %% [markdown]
# 3. Segment fissions by using Distance Map as the input intensity image and local maxima as markers to implement the Watershed algorithm

# %%
labels = preprocessing.distance_watershed(img*mask, sigma=sigma/10)
rp = measure.regionprops(labels)
centroids = np.array([region.centroid for region in rp]).round().astype(int)


title = 'watershed'
filename = base_dir+'Figures/'+title+'_t{:05}.pdf'.format(item_id)
print(filename)

fig, ax = plt.subplots(figsize=(5, 5))
ax.set_title(title.title(), size=20)
ax.imshow(label2rgb(labels, bg_label=0))
ax.plot(centroids[:, 1], centroids[:, 0], 'x', markersize=10, color='black')
ax.axis('off')
plt.tight_layout(pad=0)
plt.show()
#plt.savefig(filename)
# Out:
# H:/Santi/Figures/watershed_t00003.pdf

# %% [markdown]
# 4. Calculate mean intensity per fission and remove those below a given **threshold**.
# 5. Gaussian dilation (**sigma** is an input) of mask generated from fission centroids
# 6. Choose a **number of sigmas** to cut the gaussian dilation at a radius equal to round(dilation_nb_sigmas*sigma).
# 7. Rescale intensity so there is a smooth transition between the background and fission intensities.

# %%
#Estimate thresholds from mean and std intensity 
#mean_intensity = output_data[output_data!=0].mean()
#std_intensity = output_data[output_data!=0].std()
#weigth = np.array([-0.5, -0.25, -0.1, 0, 0.1])

#threshold = mean_intensity + weigth*std_intensity
threshold = util.load_pkl(data_path, 'mean_intensity_threshold')
# Out:
# Loading H:/Santi/Data/mean_intensity_threshold

# %%
sigma = 1.5
dilation_nb_sigmas = 2

nb_cols = len(threshold)+1
title_size = 20
cmap = 'jet'
frame = 25
labels = preprocessing.distance_watershed(output_data[frame], sigma=sigma/10)

fig, axes = plt.subplots(2, nb_cols, figsize=(nb_cols*3.5, 2*4))
for thr, ax_img, ax_labels in zip(threshold, axes[0, 1:], axes[1, 1:]):
  img_proc, fission_props = preprocessing.prepareProc(output_data[frame], sigma=sigma, dilation_nb_sigmas=dilation_nb_sigmas, threshold=thr)
  new_labels = preprocessing.segmentFissions(img_proc, fission_props, 0)
  ax_img.set_title('thr=%.1f'%thr, size=title_size)
  ax_img.imshow(img_proc, cmap=cmap)
  ax_img.axis('off')
  
  ax_labels.imshow(label2rgb(new_labels, bg_label=0)) 
  ax_labels.axis('off')

axes[1, 0].imshow(label2rgb(labels, bg_label=0))
axes[0, 0].set_title('GT', size=title_size)
axes[0, 0].imshow(output_data[frame], cmap=cmap)
axes[0, 0].axis('off')
axes[1, 0].axis('off')
  
fig.suptitle('proc_output_data [%i] | sigma=%.1f | Dilation radius=%ipx'%(frame, sigma, round(dilation_nb_sigmas*sigma)), size=title_size)
fig.subplots_adjust(wspace=0.01, hspace=0.05, top=0.8)
plt.show()

# %% [markdown]
# #### How to choose the sigma of the gaussian dilation

# %% [markdown]
# ##### Preprocess GT using different minimum spot sizes and mean intensity thresholds

# %%
sigmas = np.array([1, 1.5, 2, 2.5])
dilation_nb_sigmas = 2

threshold = util.load_pkl(data_path, 'mean_intensity_threshold')

for s in sigmas:
  for thr in threshold:
    print('\nSigma: %.1f | Threshold: %.1f'%(s, thr))
    proc_output_data, fission_props = preprocessing.prepareStack(output_data, sigma=s, dilation_nb_sigmas=dilation_nb_sigmas, threshold=thr)
    proc_labels = preprocessing.segmentFissionsStack(proc_output_data, fission_props)
    util.save_h5(proc_output_data, data_path, 'WatProc_s%.1f_t%.1f'%(s, thr))
    util.save_h5(proc_labels, data_path, 'proc_labels_s%.1f_t%.1f'%(s, thr))
    util.save_pkl(fission_props, data_path, 'fission_props_s%.1f_t%.1f'%(s, thr))
    
util.save_pkl(sigmas, data_path, 'sigmas')
# Out:
# Loading H:/Santi/Data/mean_intensity_threshold
#
# Sigma: 1.0 | Threshold: 3.5
#   0%|                                                          | 29/37000 [00:00<04:31, 135.93it/s]C:\Users\snrodrig\Documents\GitHub\MitoSplit-Net\mitosplit-net\preprocessing.py:84: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   labels = morphology.remove_small_objects(labels, 9) #Remove too small objects
# Saving H:/Santi/Data/WatProc_s1.0_t3.5.h5
# Done.
#
# Saving H:/Santi/Data/labels_s1.0_t3.5.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s1.0_t3.5
# Done.
#
# Sigma: 1.0 | Threshold: 11.3
# Saving H:/Santi/Data/WatProc_s1.0_t11.3.h5
# Done.
#
# Saving H:/Santi/Data/labels_s1.0_t11.3.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s1.0_t11.3
# Done.
#
# Sigma: 1.0 | Threshold: 16.0
# Saving H:/Santi/Data/WatProc_s1.0_t16.0.h5
# Done.
#
# Saving H:/Santi/Data/labels_s1.0_t16.0.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s1.0_t16.0
# Done.
#
# Sigma: 1.0 | Threshold: 19.1
# Saving H:/Santi/Data/WatProc_s1.0_t19.1.h5
# Done.
#
# Saving H:/Santi/Data/labels_s1.0_t19.1.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s1.0_t19.1
# Done.
#
# Sigma: 1.0 | Threshold: 22.2
# Saving H:/Santi/Data/WatProc_s1.0_t22.2.h5
# Done.
#
# Saving H:/Santi/Data/labels_s1.0_t22.2.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s1.0_t22.2
# Done.
#
# Sigma: 1.5 | Threshold: 3.5
# Saving H:/Santi/Data/WatProc_s1.5_t3.5.h5
# Done.
#
# Saving H:/Santi/Data/labels_s1.5_t3.5.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s1.5_t3.5
# Done.
#
# Sigma: 1.5 | Threshold: 11.3
# Saving H:/Santi/Data/WatProc_s1.5_t11.3.h5
# Done.
#
# Saving H:/Santi/Data/labels_s1.5_t11.3.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s1.5_t11.3
# Done.
#
# Sigma: 1.5 | Threshold: 16.0
# Saving H:/Santi/Data/WatProc_s1.5_t16.0.h5
# Done.
#
# Saving H:/Santi/Data/labels_s1.5_t16.0.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s1.5_t16.0
# Done.
#
# Sigma: 1.5 | Threshold: 19.1
# Saving H:/Santi/Data/WatProc_s1.5_t19.1.h5
# Done.
#
# Saving H:/Santi/Data/labels_s1.5_t19.1.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s1.5_t19.1
# Done.
#
# Sigma: 1.5 | Threshold: 22.2
# Saving H:/Santi/Data/WatProc_s1.5_t22.2.h5
# Done.
#
# Saving H:/Santi/Data/labels_s1.5_t22.2.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s1.5_t22.2
# Done.
#
# Sigma: 2.0 | Threshold: 3.5
# Saving H:/Santi/Data/WatProc_s2.0_t3.5.h5
# Done.
#
# Saving H:/Santi/Data/labels_s2.0_t3.5.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s2.0_t3.5
# Done.
#
# Sigma: 2.0 | Threshold: 11.3
# Saving H:/Santi/Data/WatProc_s2.0_t11.3.h5
# Done.
#
# Saving H:/Santi/Data/labels_s2.0_t11.3.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s2.0_t11.3
# Done.
#
# Sigma: 2.0 | Threshold: 16.0
# Saving H:/Santi/Data/WatProc_s2.0_t16.0.h5
# Done.
#
# Saving H:/Santi/Data/labels_s2.0_t16.0.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s2.0_t16.0
# Done.
#
# Sigma: 2.0 | Threshold: 19.1
# Saving H:/Santi/Data/WatProc_s2.0_t19.1.h5
# Done.
#
# Saving H:/Santi/Data/labels_s2.0_t19.1.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s2.0_t19.1
# Done.
#
# Sigma: 2.0 | Threshold: 22.2
# Saving H:/Santi/Data/WatProc_s2.0_t22.2.h5
# Done.
#
# Saving H:/Santi/Data/labels_s2.0_t22.2.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s2.0_t22.2
# Done.
#
# Sigma: 2.5 | Threshold: 3.5
# Saving H:/Santi/Data/WatProc_s2.5_t3.5.h5
# Done.
#
# Saving H:/Santi/Data/labels_s2.5_t3.5.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s2.5_t3.5
# Done.
#
# Sigma: 2.5 | Threshold: 11.3
# Saving H:/Santi/Data/WatProc_s2.5_t11.3.h5
# Done.
#
# Saving H:/Santi/Data/labels_s2.5_t11.3.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s2.5_t11.3
# Done.
#
# Sigma: 2.5 | Threshold: 16.0
# Saving H:/Santi/Data/WatProc_s2.5_t16.0.h5
# Done.
#
# Saving H:/Santi/Data/labels_s2.5_t16.0.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s2.5_t16.0
# Done.
#
# Sigma: 2.5 | Threshold: 19.1
# Saving H:/Santi/Data/WatProc_s2.5_t19.1.h5
# Done.
#
# Saving H:/Santi/Data/labels_s2.5_t19.1.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s2.5_t19.1
# Done.
#
# Sigma: 2.5 | Threshold: 22.2
# Saving H:/Santi/Data/WatProc_s2.5_t22.2.h5
# Done.
#
# Saving H:/Santi/Data/labels_s2.5_t22.2.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s2.5_t22.2
# Done.
#
# Saving H:/Santi/Data/sigmas
# Done.

# %% [markdown]
# ##### How to choose the optimal sigma for gaussian dilation given a mean intensity threshold

# %% [markdown]
# In this section, we compare the mean diameter of all fissions in the GT to the one calculated from the different preprocessed outputs.
#
# 1) Load sigmas used  and thresholds used in the previous stage of the preprocessing

# %%
sigmas = util.load_pkl(data_path, 'sigmas')
threshold = util.load_pkl(data_path, 'mean_intensity_threshold')
nb_sigmas = sigmas.shape[0]
nb_thresholds = threshold.shape[0]

fission_props_filename, proc_output_data_filename, proc_labels_filename = [], [], []
for s in sigmas:
  for t in threshold:
    fission_props_filename += ['fission_props_s%.1f_t%.1f'%(s, t)]
    proc_output_data_filename += ['WatProc_s%.1f_t%.1f'%(s, t)]
    proc_labels_filename += ['proc_labels_s%.1f_t%.1f'%(s, t)]
    
indices = np.sort(np.random.choice(output_data.shape[0], 2000, replace=False))
fission_props = util.load_pkl(data_path, fission_props_filename, as_type=np.ndarray)[:, indices]
proc_output_data = util.load_h5(data_path, proc_output_data_filename, indices)
proc_labels = util.load_h5(data_path, proc_labels_filename, indices)
# Out:
# Loading H:/Santi/Data/sigmas
#
# Loading H:/Santi/Data/mean_intensity_threshold
#
# Loading H:/Santi/Data/fission_props_s1.0_t3.5
#
# Loading H:/Santi/Data/fission_props_s1.0_t11.3
#
# Loading H:/Santi/Data/fission_props_s1.0_t16.0
#
# Loading H:/Santi/Data/fission_props_s1.0_t19.1
#
# Loading H:/Santi/Data/fission_props_s1.0_t22.2
#
# Loading H:/Santi/Data/fission_props_s1.5_t3.5
#
# Loading H:/Santi/Data/fission_props_s1.5_t11.3
#
# Loading H:/Santi/Data/fission_props_s1.5_t16.0
#
# Loading H:/Santi/Data/fission_props_s1.5_t19.1
#
# Loading H:/Santi/Data/fission_props_s1.5_t22.2
#
# Loading H:/Santi/Data/fission_props_s2.0_t3.5
#
# Loading H:/Santi/Data/fission_props_s2.0_t11.3
#
# Loading H:/Santi/Data/fission_props_s2.0_t16.0
#
# Loading H:/Santi/Data/fission_props_s2.0_t19.1
#
# Loading H:/Santi/Data/fission_props_s2.0_t22.2
#
# Loading H:/Santi/Data/fission_props_s2.5_t3.5
#
# Loading H:/Santi/Data/fission_props_s2.5_t11.3
#
# Loading H:/Santi/Data/fission_props_s2.5_t16.0
#
# Loading H:/Santi/Data/fission_props_s2.5_t19.1
#
# Loading H:/Santi/Data/fission_props_s2.5_t22.2
# Done.
#
# Loading H:/Santi/Data/WatProc_s1.0_t3.5.h5
#
# Loading H:/Santi/Data/WatProc_s1.0_t11.3.h5
#
# Loading H:/Santi/Data/WatProc_s1.0_t16.0.h5
#
# Loading H:/Santi/Data/WatProc_s1.0_t19.1.h5
#
# Loading H:/Santi/Data/WatProc_s1.0_t22.2.h5
#
# Loading H:/Santi/Data/WatProc_s1.5_t3.5.h5
#
# Loading H:/Santi/Data/WatProc_s1.5_t11.3.h5
#
# Loading H:/Santi/Data/WatProc_s1.5_t16.0.h5
#
# Loading H:/Santi/Data/WatProc_s1.5_t19.1.h5
#
# Loading H:/Santi/Data/WatProc_s1.5_t22.2.h5
#
# Loading H:/Santi/Data/WatProc_s2.0_t3.5.h5
#
# Loading H:/Santi/Data/WatProc_s2.0_t11.3.h5
#
# Loading H:/Santi/Data/WatProc_s2.0_t16.0.h5
#
# Loading H:/Santi/Data/WatProc_s2.0_t19.1.h5
#
# Loading H:/Santi/Data/WatProc_s2.0_t22.2.h5
#
# Loading H:/Santi/Data/WatProc_s2.5_t3.5.h5
#
# Loading H:/Santi/Data/WatProc_s2.5_t11.3.h5
#
# Loading H:/Santi/Data/WatProc_s2.5_t16.0.h5
#
# Loading H:/Santi/Data/WatProc_s2.5_t19.1.h5
#
# Loading H:/Santi/Data/WatProc_s2.5_t22.2.h5
#
# Loading H:/Santi/Data/labels_s1.0_t3.5.h5
#
# Loading H:/Santi/Data/labels_s1.0_t11.3.h5
#
# Loading H:/Santi/Data/labels_s1.0_t16.0.h5
#
# Loading H:/Santi/Data/labels_s1.0_t19.1.h5
#
# Loading H:/Santi/Data/labels_s1.0_t22.2.h5
#
# Loading H:/Santi/Data/labels_s1.5_t3.5.h5
#
# Loading H:/Santi/Data/labels_s1.5_t11.3.h5
#
# Loading H:/Santi/Data/labels_s1.5_t16.0.h5
#
# Loading H:/Santi/Data/labels_s1.5_t19.1.h5
#
# Loading H:/Santi/Data/labels_s1.5_t22.2.h5
#
# Loading H:/Santi/Data/labels_s2.0_t3.5.h5
#
# Loading H:/Santi/Data/labels_s2.0_t11.3.h5
#
# Loading H:/Santi/Data/labels_s2.0_t16.0.h5
#
# Loading H:/Santi/Data/labels_s2.0_t19.1.h5
#
# Loading H:/Santi/Data/labels_s2.0_t22.2.h5
#
# Loading H:/Santi/Data/labels_s2.5_t3.5.h5
#
# Loading H:/Santi/Data/labels_s2.5_t11.3.h5
#
# Loading H:/Santi/Data/labels_s2.5_t16.0.h5
#
# Loading H:/Santi/Data/labels_s2.5_t19.1.h5
#
# Loading H:/Santi/Data/labels_s2.5_t22.2.h5

# %%
frame = np.random.randint(0, proc_output_data.shape[1])
nb_sigmas_threshold_ratio = 0.8*nb_sigmas/nb_thresholds
space = 0.05
width = 3
title_size = 20
cmap = 'jet'

fig, axes = plt.subplots(nb_sigmas, nb_thresholds, figsize=(width*nb_sigmas*(1+space), width*nb_thresholds*(nb_sigmas_threshold_ratio+space)))
fig.suptitle('proc_output_data [%i]'%frame, size=title_size)

for s_id in range(nb_sigmas):
  for t_id in range(nb_thresholds):
    axes[s_id, t_id].imshow(proc_output_data[t_id+s_id*nb_thresholds][frame], cmap=cmap, aspect='equal')
    axes[s_id, t_id].set(xticks=[], yticks=[])
    
for t_id in range(nb_thresholds):
  axes[0, t_id].set_title('%.1f'%threshold[t_id], size=title_size)
  
for s_id in range(nb_sigmas):
  axes[s_id, 0].set_ylabel('%.1f'%sigmas[s_id], size=title_size)
  
fig.text(0.5, 0.86, 'Mean intensity threshold', fontsize=title_size, ha='center')
fig.text(0.03, 0.5, 'Sigmas', fontsize=title_size, va='center', rotation=90)
fig.subplots_adjust(hspace=space, wspace=space, top=0.8, left=0.1)
plt.show()

# %%
nb_sigmas_threshold_ratio = 0.8*nb_sigmas/nb_thresholds
space = 0.05
width = 3
title_size = 20
cmap = 'jet'

fig, axes = plt.subplots(nb_sigmas, nb_thresholds, figsize=(width*nb_sigmas*(1+space), width*nb_thresholds*(nb_sigmas_threshold_ratio+space)))
fig.suptitle('proc_labels [%i]'%frame, size=title_size)

for s_id in range(nb_sigmas):
  for t_id in range(nb_thresholds):
    axes[s_id, t_id].imshow(label2rgb(proc_labels[t_id+s_id*nb_thresholds][frame], bg_label=0))
    axes[s_id, t_id].set(xticks=[], yticks=[])
    
for t_id in range(nb_thresholds):
  axes[0, t_id].set_title('%.1f'%threshold[t_id], size=title_size)
  
for s_id in range(nb_sigmas):
  axes[s_id, 0].set_ylabel('%.1f'%sigmas[s_id], size=title_size)
  
fig.text(0.5, 0.86, 'Mean intensity threshold', fontsize=title_size, ha='center')
fig.text(0.03, 0.5, 'Sigmas', fontsize=title_size, va='center', rotation=90)
fig.subplots_adjust(hspace=space, wspace=space, top=0.8, left=0.1)
plt.show()

# %% [markdown]
# 2) Calculate properties of outputs (GT was already analyzed before. See files 'fission_props_*')

# %%
proc_fission_props = []
print('Getting properties...')
for i in range(proc_output_data.shape[0]):
    print('\n'+proc_labels_filename[i])
    props = preprocessing.analyzeFissionsStack(proc_labels[i])
    proc_fission_props += [props] 
    util.save_pkl(props, data_path, 'proc_fission_props_s%s'%proc_labels_filename[i].split('_s')[-1],)
# Out:
# Getting properties...
#
# labels_s1.0_t3.5
# Saving H:/Santi/Data/proc_fission_props_s1.0_t3.5
# Done.
#
# labels_s1.0_t11.3
# Saving H:/Santi/Data/proc_fission_props_s1.0_t11.3
# Done.
#
# labels_s1.0_t16.0
# Saving H:/Santi/Data/proc_fission_props_s1.0_t16.0
# Done.
#
# labels_s1.0_t19.1
# Saving H:/Santi/Data/proc_fission_props_s1.0_t19.1
# Done.
#
# labels_s1.0_t22.2
# Saving H:/Santi/Data/proc_fission_props_s1.0_t22.2
# Done.
#
# labels_s1.5_t3.5
# Saving H:/Santi/Data/proc_fission_props_s1.5_t3.5
# Done.
#
# labels_s1.5_t11.3
# Saving H:/Santi/Data/proc_fission_props_s1.5_t11.3
# Done.
#
# labels_s1.5_t16.0
# Saving H:/Santi/Data/proc_fission_props_s1.5_t16.0
# Done.
#
# labels_s1.5_t19.1
# Saving H:/Santi/Data/proc_fission_props_s1.5_t19.1
# Done.
#
# labels_s1.5_t22.2
# Saving H:/Santi/Data/proc_fission_props_s1.5_t22.2
# Done.
#
# labels_s2.0_t3.5
# Saving H:/Santi/Data/proc_fission_props_s2.0_t3.5
# Done.
#
# labels_s2.0_t11.3
# Saving H:/Santi/Data/proc_fission_props_s2.0_t11.3
# Done.
#
# labels_s2.0_t16.0
# Saving H:/Santi/Data/proc_fission_props_s2.0_t16.0
# Done.
#
# labels_s2.0_t19.1
# Saving H:/Santi/Data/proc_fission_props_s2.0_t19.1
# Done.
#
# labels_s2.0_t22.2
# Saving H:/Santi/Data/proc_fission_props_s2.0_t22.2
# Done.
#
# labels_s2.5_t3.5
# Saving H:/Santi/Data/proc_fission_props_s2.5_t3.5
# Done.
#
# labels_s2.5_t11.3
# Saving H:/Santi/Data/proc_fission_props_s2.5_t11.3
# Done.
#
# labels_s2.5_t16.0
# Saving H:/Santi/Data/proc_fission_props_s2.5_t16.0
# Done.
#
# labels_s2.5_t19.1
# Saving H:/Santi/Data/proc_fission_props_s2.5_t19.1
# Done.
#
# labels_s2.5_t22.2
# Saving H:/Santi/Data/proc_fission_props_s2.5_t22.2
# Done.

# %%
#Loading processed statistics
proc_fission_props_filename = []

for s in sigmas:
  for t in threshold:
    proc_fission_props_filename += ['proc_fission_props_s%.1f_t%.1f'%(s, t)]
    
proc_fission_props = util.load_pkl(data_path, proc_fission_props_filename, as_type=np.ndarray)
# Out:
# Loading H:/Santi/Data/proc_fission_props_s1.0_t3.5
#
# Loading H:/Santi/Data/proc_fission_props_s1.0_t11.3
#
# Loading H:/Santi/Data/proc_fission_props_s1.0_t16.0
#
# Loading H:/Santi/Data/proc_fission_props_s1.0_t19.1
#
# Loading H:/Santi/Data/proc_fission_props_s1.0_t22.2
#
# Loading H:/Santi/Data/proc_fission_props_s1.5_t3.5
#
# Loading H:/Santi/Data/proc_fission_props_s1.5_t11.3
#
# Loading H:/Santi/Data/proc_fission_props_s1.5_t16.0
#
# Loading H:/Santi/Data/proc_fission_props_s1.5_t19.1
#
# Loading H:/Santi/Data/proc_fission_props_s1.5_t22.2
#
# Loading H:/Santi/Data/proc_fission_props_s2.0_t3.5
#
# Loading H:/Santi/Data/proc_fission_props_s2.0_t11.3
#
# Loading H:/Santi/Data/proc_fission_props_s2.0_t16.0
#
# Loading H:/Santi/Data/proc_fission_props_s2.0_t19.1
#
# Loading H:/Santi/Data/proc_fission_props_s2.0_t22.2
#
# Loading H:/Santi/Data/proc_fission_props_s2.5_t3.5
#
# Loading H:/Santi/Data/proc_fission_props_s2.5_t11.3
#
# Loading H:/Santi/Data/proc_fission_props_s2.5_t16.0
#
# Loading H:/Santi/Data/proc_fission_props_s2.5_t19.1
#
# Loading H:/Santi/Data/proc_fission_props_s2.5_t22.2
# Done.

# %%
nb_img = proc_output_data.shape[1]
diameter = []
proc_diameter = []

print('Calculating mean diameter')
for s_id in range(nb_sigmas):
  for t_id in range(nb_thresholds):
    print('s=%.1f | t=%.1f'%(sigmas[s_id], threshold[t_id]))
    i = t_id+s_id*nb_thresholds #Index corresponding to sigma=sigmas[s_id], thr=threshold[t_id]
    diameter += [[]]
    proc_diameter += [[]]
    for frame in tqdm(range(nb_img), total=nb_img):
      if len(fission_props[i][frame])>0:
        diameter[-1] += list(fission_props[i][frame]['equivalent_diameter'])
        proc_diameter[-1] += list(proc_fission_props[i][frame]['equivalent_diameter'])
# Out:
# Calculating mean diameter
# s=1.0 | t=3.5
# s=1.0 | t=11.3
# s=1.0 | t=16.0
# s=1.0 | t=19.1
# s=1.0 | t=22.2
# s=1.5 | t=3.5
# s=1.5 | t=11.3
# s=1.5 | t=16.0
# s=1.5 | t=19.1
# s=1.5 | t=22.2
# s=2.0 | t=3.5
# s=2.0 | t=11.3
# s=2.0 | t=16.0
# s=2.0 | t=19.1
# s=2.0 | t=22.2
# s=2.5 | t=3.5
# s=2.5 | t=11.3
# s=2.5 | t=16.0
# s=2.5 | t=19.1
# s=2.5 | t=22.2

# %% [markdown]
# To compare GT with the processed outputs, we calculate the diameter ratio as
#
# $$\text{Diameter ratio }(\sigma) = \dfrac{\langle d_{{PROC}}(\sigma) \rangle}{\langle d \rangle}$$
#
# where $d$ and $d_{PROC}$ are the mean diameter of the GT and the processed output, respectively.

# %%
id_sort = np.array([[t_id+s_id*nb_thresholds for t_id in range(nb_thresholds)] for s_id in range(nb_sigmas)])
#d
mean_diameter = np.array([np.mean(d) for d in diameter])
#mean_diameter_err = np.array([np.mean(d)/len(d) for d in diameter])[id_sort]

#d_proc
mean_proc_diameter = np.array([np.mean(d_proc) for d_proc in proc_diameter])

#Diameter ratio
diam_ratio = (mean_proc_diameter/mean_diameter)[id_sort]
#diam_ratio_err = mean_proc_diameter*mean_diameter_err/(mean_diameter**2)

# %% [markdown]
# To determine the optimal sigma, we ask fission sites in the processed output to have the same mean diameter as in the GT. Therefore, the optimal sigma $\sigma_{opt}$ satisfies the condition
#
# $$\text{Diameter ratio }(\sigma_{opt}) = 1 $$

# %%
a, b = np.polyfit(sigmas, diam_ratio, 1)

optimal_sigma = (1-b)/a
for t, s_opt in zip(threshold, optimal_sigma):
  print('t=%.1f | s_opt = %.4f'%(t, s_opt))
  
util.save_pkl(optimal_sigma, data_path, 'optimal_sigma')
# Out:
# t=3.5 | s_opt = 1.9065
# t=11.3 | s_opt = 2.0851
# t=16.0 | s_opt = 2.1631
# t=19.1 | s_opt = 2.1967
# t=22.2 | s_opt = 2.2274
#
# Saving H:/Santi/Data/optimal_sigma
# Done.

# %%
cmap_scatter = plt.cm.ScalarMappable(cmap='Greys', norm=Normalize(threshold.min(), threshold.max()))
cmap_linear_fit = plt.cm.ScalarMappable(cmap='Reds', norm=Normalize(threshold.min(), threshold.max()))
cmap_optimal_sigma = plt.cm.ScalarMappable(cmap='Purples', norm=Normalize(threshold.min(), threshold.max()))

t_step = (threshold[1]-threshold[0])/nb_thresholds

fig, ax = plt.subplots(figsize=(8, 6))

#Linear fit
for i in range(nb_thresholds):
  t_weight = threshold[i]/threshold[-1] #Defines color from cmap
  scatter = ax.plot(sigmas, diam_ratio[:, i], 'o', color=cmap_scatter.get_cmap()(t_weight))[0]
  line = ax.plot(sigmas, a[i]*sigmas+b[i], color=cmap_linear_fit.get_cmap()(t_weight))[0]
  optimal_sigma_line = ax.axvline(optimal_sigma[i], ls='-', color=cmap_optimal_sigma.get_cmap()(t_weight))
  
cbar = fig.colorbar(cmap_scatter, ax=ax, ticks=threshold)
ticklabels = np.round(threshold, 1)
cbar.ax.set_yticklabels(ticklabels)
cbar.set_label('Probability threshold', labelpad=10)

#Optimal ratio=1  
ax.axhline(1, ls='--', color='black', lw=1, alpha=0.7, label='Optimal ratio')

#Optimal sigma
#markerline, stemlines, baseline = ax.stem(optimal_sigma, np.ones_like(optimal_sigma)*diam_ratio.min(), markerfmt='none', basefmt='none')
#plt.setp(stemlines, color=cmap_scatter.get_cmap()(threshold/threshold[-1]), linewidth=2)


scatter.set_label('Data')
line.set_label('Linear fit')
optimal_sigma_line.set_label('Optimal sigma')
ax.set(xlabel=r'$\sigma$', ylabel=r'$\dfrac{\langle d_{{PROC}} \rangle}{\langle d \rangle}$')
ax.set_ylim([0, 2])
ax.legend()
fig.subplots_adjust(wspace=0.05)

plt.show()

# %% [markdown]
# ##### Results: filtered events using optimal sigma for each threshold

# %%
optimal_sigma = util.load_pkl(data_path, 'optimal_sigma')
dilation_nb_sigmas = 2

threshold = util.load_pkl(data_path, 'mean_intensity_threshold')

for s, t in zip(optimal_sigma, threshold):
  print('\nSigma: %.1f | Threshold: %.1f'%(s, t))
  print('    Prepare stack...')
  proc_output_data, fission_props = preprocessing.prepareStack(output_data, sigma=s, dilation_nb_sigmas=dilation_nb_sigmas, threshold=t)
  print('    Segment fissions...')
  labels = preprocessing.segmentFissionsStack(output_data*segmentation.clear_border(output_data>0), fission_props, sigma=s/10)
  print('    Segment processed fissions...')
  proc_labels = preprocessing.segmentFissionsStack(proc_output_data, fission_props)
  util.save_h5(proc_output_data, data_path, 'WatProc_s%.1f_t%.1f'%(s, t))
  util.save_h5(labels, data_path, 'labels_s%.1f_t%.1f'%(s, t))
  util.save_h5(proc_labels, data_path, 'proc_labels_s%.1f_t%.1f'%(s, t))
  util.save_pkl(fission_props, data_path, 'fission_props_s%.1f_t%.1f'%(s, t))
# Out:
# Loading H:/Santi/Data/optimal_sigma
#
# Loading H:/Santi/Data/mean_intensity_threshold
#
# Sigma: 1.9 | Threshold: 3.5
#     Prepare stack...
#   0%|                                                          | 37/37000 [00:00<05:20, 115.46it/s]C:\Users\snrodrig\Documents\GitHub\MitoSplit-Net\mitosplit-net\preprocessing.py:84: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   labels = morphology.remove_small_objects(labels, 9) #Remove too small objects
#     Segment fissions...
#     Segment processed fissions...
# Saving H:/Santi/Data/WatProc_s1.9_t3.5.h5
# Done.
#
# Saving H:/Santi/Data/labels_s1.9_t3.5.h5
# Done.
#
# Saving H:/Santi/Data/proc_labels_s1.9_t3.5.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s1.9_t3.5
# Done.
#
# Sigma: 2.1 | Threshold: 11.3
#     Prepare stack...
#     Segment fissions...
#     Segment processed fissions...
# Saving H:/Santi/Data/WatProc_s2.1_t11.3.h5
# Done.
#
# Saving H:/Santi/Data/labels_s2.1_t11.3.h5
# Done.
#
# Saving H:/Santi/Data/proc_labels_s2.1_t11.3.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s2.1_t11.3
# Done.
#
# Sigma: 2.2 | Threshold: 16.0
#     Prepare stack...
#     Segment fissions...
#     Segment processed fissions...
# Saving H:/Santi/Data/WatProc_s2.2_t16.0.h5
# Done.
#
# Saving H:/Santi/Data/labels_s2.2_t16.0.h5
# Done.
#
# Saving H:/Santi/Data/proc_labels_s2.2_t16.0.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s2.2_t16.0
# Done.
#
# Sigma: 2.2 | Threshold: 19.1
#     Prepare stack...
#     Segment fissions...
#     Segment processed fissions...
# Saving H:/Santi/Data/WatProc_s2.2_t19.1.h5
# Done.
#
# Saving H:/Santi/Data/labels_s2.2_t19.1.h5
# Done.
#
# Saving H:/Santi/Data/proc_labels_s2.2_t19.1.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s2.2_t19.1
# Done.
#
# Sigma: 2.2 | Threshold: 22.2
#     Prepare stack...
#     Segment fissions...
#     Segment processed fissions...
# Saving H:/Santi/Data/WatProc_s2.2_t22.2.h5
# Done.
#
# Saving H:/Santi/Data/labels_s2.2_t22.2.h5
# Done.
#
# Saving H:/Santi/Data/proc_labels_s2.2_t22.2.h5
# Done.
#
# Saving H:/Santi/Data/fission_props_s2.2_t22.2
# Done.

# %% [markdown]
# ### Temporal median filter

# %% [markdown]
# Removing events that are not probably fissions doesn't use all the information we know about this process. One main aspect that was not considered before is that mitochondrial divisions last for a certain period of time. Therefore, the temporal binary signal that results from classifying frames as 'active' or 'inactive' shouldn't include short peaks ore noise. Here we show that a underestimating this factor introduces noise and how to fix it with a temporal median filter.

# %%
division_mask = proc_output_data!=0
binary_output = (np.any(np.any(division_mask, axis=1), axis=1))

#Active/inactive percentages in binary_output
print('Active: %.2f%%\nInactive: %.2f%%'%util.activity_percent(binary_output))
# Out:
# Active: 64.88%
# Inactive: 35.12%

# %%
nb_img = input_data.shape[0]
mean_output_data = np.zeros(nb_img)
for frame in tqdm(np.where(binary_output)[0]):
  mean_output_data[frame] = np.mean(proc_output_data[frame])

#Automatic thresholding with Otsu's method
mean_output_threshold = filters.threshold_multiotsu(mean_output_data, classes=3)[1] #Keep frames with high probability of division
binary_output = mean_output_data>mean_output_threshold
# Out:
#   0%|          | 0/24004 [00:00<?, ?it/s]

# %%
frames = np.arange(250, 500)
legend_loc = 'lower right'

fig = plt.figure(figsize=(15,8))
fig.suptitle('Mitochondrial division activity', size=20)

gs = fig.add_gridspec(2, 1, height_ratios=[1, 10], hspace=0)
ax_mean = fig.add_subplot(gs[1])
ax_binary = fig.add_subplot(gs[0], sharex=ax_mean)

#GT mean signal and temporal median filtering
ax_mean.plot(frames, mean_output_data[frames], 'o-', color='black', label='Mean')
ax_mean.axhline(mean_output_threshold, ls='--', color='black', label='Threshold')
ax_mean.set(xlabel='Frame', ylabel='Output')
ax_mean.legend(loc=legend_loc)

#Derived mitochondrial division activity by thresholding
ax_binary.fill_between(frames, 0, 1, where=binary_output[frames], color='blue', alpha=0.15)

ax_binary.axis('off')  

plt.show()

# %%
window_size = 7
filtered_mean_output = ndi.median_filter(mean_output_data, size=window_size)
mean_output_threshold = filters.threshold_multiotsu(filtered_mean_output, classes=3)[1]

print('Threshold: %.3f'%mean_output_threshold)
binary_output = mean_output_data>mean_output_threshold
filtered_binary_output = filtered_mean_output>mean_output_threshold

#Active/inactive percentages in filtered_binary_output
print('\nWithout temporal median filter')
print('Active: %.2f%%\nInactive: %.2f%%'%util.activity_percent(binary_output))
print('\nWith temporal median filter')
print('Active: %.2f%%\nInactive: %.2f%%'%util.activity_percent(filtered_binary_output))
# Out:
# Threshold: 0.578
#
# Without temporal median filter
# Active: 15.33%
# Inactive: 84.67%
#
# With temporal median filter
# Active: 13.34%
# Inactive: 86.66%

# %%
fig = plt.figure(figsize=(15,8))
fig.suptitle('Mitochondrial division activity', size=20)

gs = fig.add_gridspec(2, 1, height_ratios=[1, 10], hspace=0)
ax_mean = fig.add_subplot(gs[1])
ax_binary = fig.add_subplot(gs[0], sharex=ax_mean)

#GT mean signal and temporal median filtering
ax_mean.plot(frames, mean_output_data[frames], 'o-', color='black', label='Mean')
ax_mean.plot(frames, filtered_mean_output[frames], 'o-', color='darkviolet', label='Temporal median filter\nWindow size: %i'%window_size)
ax_mean.axhline(mean_output_threshold, ls='--', color='black', label='Threshold=%.1f'%mean_output_threshold)
ax_mean.set(xlabel='Frame', ylabel='Output')
ax_mean.legend(loc=legend_loc)

#Derived mitochondrial division activity by thresholding

ax_binary.fill_between(frames, 0, 1, where=binary_output[frames], color='blue', alpha=0.6)
ax_binary.fill_between(frames, 0, 1, where=filtered_binary_output[frames], color='red', alpha=0.4)

ax_binary.axis('off')
plt.show()

# %% [markdown]
# To determine if the removed positives were noise, we analyzed the mean duration of the removed sequences of frames. If the removed frames corresponded to division, their mean duration should be longer that 1 frame. In this case, we see that it doesn't happen, as the mean duration is 1.41 frames:

# %% [markdown]
# filtered_positives = binary_output & ~filtered_binary_output
# percent_filtered_positives = 100*(filtered_positives).sum()/(binary_output.sum())
# #Mean duration of filtered positives
# mean_duration = util.sequence_length(filtered_positives).mean()
# print('Positives removed by temporal median filter: %.2f%%'%percent_filtered_positives)
# print('Mean duration of removed positives: %.2f frames'%mean_duration)

# %% [markdown]
# #### Visualization of pixels that were turned off (Active -> Inactive) and on (Inactive -> Active) because of the temporal median filter

# %%
nb_frames = 4
item_id_active = frames[np.where(~binary_output[frames] & filtered_binary_output[frames])[0][:nb_frames ]]
item_id_inactive = frames[np.where(binary_output[frames] & ~filtered_binary_output[frames])[0][:nb_frames ]]
fig, axes = plt.subplots(nb_frames, 2, figsize=(5*2, 5*nb_frames))

for frame_active, frame_inactive, input_active, input_inactive, output_active, output_inactive, ax in zip(item_id_active, item_id_inactive, input_data[item_id_active], input_data[item_id_inactive], 
                                                                                                          proc_output_data[item_id_active], proc_output_data[item_id_inactive], axes):
  plotting.plot_merge(input_inactive, output_inactive, ax=ax[0], title='Active'+r'$\rightarrow$'+'Inactive', frame=frame_inactive)
  plotting.plot_merge(input_active, output_active, ax=ax[1], title='Inactive'+r'$\rightarrow$'+'Active', frame=frame_active)
  
fig.subplots_adjust(wspace=0)

# %%
nb_examples = 3
item_id = [317, 324, 328]
size = nb_examples*3
fig, axes = plt.subplots(nb_examples, nb_examples, figsize=(size, size))
for i, frame in enumerate(item_id):
  plotting.plot_comparison(input_data[frame], proc_output_data[frame], merge=True, axes=axes[:, i])
  axes[0, i].set_title('$t=%i$'%frame, size=20)
  axes[1, i].set_title('')
  axes[2, i].set_title('')

fig.subplots_adjust(left=0, right=1, top=0.96, bottom=0.01, wspace=0.05, hspace=0.01)
plt.show()
#fig.savefig(new_data_path+'division_example.pdf')

# %% [markdown]
# #### How to choose the window size

# %%
inactive_output_data = filtered_mean_output[binary_output==False]
nonzero_inactive_output_data = filtered_mean_output[(binary_output==False)&(filtered_mean_output>0)]

nbins = 7

xlabel=['Inactive output data', 'Inactive output data > 0']
ylabel=['Frequency', None]
fig, axes = plt.subplots(1, 2, figsize=(5*2, 5), sharey=True)

for inactive_data, xlab, ylab, ax in zip([inactive_output_data, nonzero_inactive_output_data], xlabel, ylabel, axes):
  inactive_output_bins = np.linspace(inactive_data.min(), inactive_data.max(), nbins, endpoint=True)
  inactive_output_bincenters, inactive_output_hist = util.norm_histogram(inactive_output_bins, inactive_data)[:2]
  binwidth= np.diff(inactive_output_bins)
  plotting.plot_histogram(inactive_output_bincenters, binwidth*inactive_output_hist, xlabel=xlab, ylabel=ylab, ax=ax)

inactive_mean, inactive_std = nonzero_inactive_output_data.mean(), nonzero_inactive_output_data.std()
axes[1].axvline(inactive_mean, ls='--', color='orange', label='Mean')
axes[1].axvspan(inactive_mean-inactive_std, inactive_mean+inactive_std, color='orange', alpha=0.2, label='')
axes[1].legend(loc='upper right')
plt.subplots_adjust(wspace=0.1)
plt.show()

# %%
window_size = np.arange(2, 100)
nonzero_inactivity_std = np.zeros_like(window_size, dtype=float)

for i, size in enumerate(window_size):
  filtered_mean_output = ndi.median_filter(mean_output_data, size=size)
  nonzero_inactive_output_data = filtered_mean_output[(mean_output_data==0)&(filtered_mean_output>0)]
  nonzero_inactivity_std[i] = nonzero_inactive_output_data.std()

# %%
optimal_id = nonzero_inactivity_std==nonzero_inactivity_std.min()
optimal_window_size = window_size[optimal_id][0]
fig, ax = plt.subplots(figsize=(7, 6), sharex=True)
ax.plot(window_size, nonzero_inactivity_std, 'o-')
ax.set(xlabel='Window size', ylabel='$\sigma$ of inactive\noutput data > 0')
ax.axvline(optimal_window_size, ls='--', color='black', label='Optimal window size: %i'%optimal_window_size)
ax.legend()
fig.subplots_adjust(wspace=0.4)

plt.show()
