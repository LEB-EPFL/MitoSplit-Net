# %% [markdown]
# # Data augmentation

# %%
import util
import plotting
import augmentation

import numpy as np
import matplotlib.pyplot as plt
from skimage.color import label2rgb

from albumentations import Compose, Rotate, RandomRotate90, HorizontalFlip, Flip, ElasticTransform, GaussNoise, Crop, Resize

# %% [markdown]
# ## Define augmentation pipeline

# %% [markdown]
# 'p' is the probability that the operation is performed

# %%
img_size = 128
transform = Compose([Rotate(limit=40, p=0.5), 
                    RandomRotate90(p=0.5), 
                    HorizontalFlip(p=0.5),
                    Flip(p=0.5),
                    ElasticTransform(sigma=10, alpha_affine=15, p=1),
                    Crop(x_max=img_size, y_max=img_size, p=0.5), 
                    Resize(img_size, img_size)], 
                   additional_targets={'image': 'image', 'image0': 'image', 'mask':'mask'})

#Noise will only be aplied to input_data
noise_transform = GaussNoise(var_limit=(50.0, 100.0), p=0.5)

# %% [markdown]
# ## Load and augment data

# %% [markdown]
# ### Example

# %%
base_dir = 'H:/Santi/'
data_path = base_dir+'Data/' 

indices = [3, 25, 26286, 34136]
optimal_sigma = util.load_pkl(data_path, 'optimal_sigma')
threshold = util.load_pkl(data_path, 'mean_intensity_threshold')

item_id = 0
s, t = optimal_sigma[item_id], threshold[item_id]

#Inputs
input_data = util.load_h5(data_path, 'Mito', indices)
print('Inputs'+':', input_data.shape)

#Outputs
output_data = util.load_h5(data_path, 'WatProc_s%.1f_t%.1f'%(s, t), indices)
print('Outputs:', output_data.shape)

#Labels
labels = util.load_h5(data_path, 'proc_labels_s%.1f_t%.1f'%(s, t), indices)
print('Outputs:', labels.shape)
# Out:
# Loading H:/Santi/Data/optimal_sigma
#
# Loading H:/Santi/Data/mean_intensity_threshold
#
# Loading H:/Santi/Data/Mito.h5
# Converting to array
# Inputs: (4, 128, 128)
#
# Loading H:/Santi/Data/WatProc_s1.9_t3.5.h5
# Converting to array
# Outputs: (4, 128, 128)
#
# Loading H:/Santi/Data/proc_labels_s1.9_t3.5.h5
# Converting to array
# Outputs: (4, 128, 128)

# %%
aug_input_data, aug_output_data, aug_labels = augmentation.augStack(input_data, output_data, labels, transform, noise_transform, sigma=s)

nb_img = input_data.shape[0]
title_size=20
width = 5

fig, axes = plt.subplots(nb_img, 3, figsize=(width*3, width*nb_img))
for frame in range(input_data.shape[0]):
  plotting.plot_merge(input_data[frame], output_data[frame], title='', ax=axes[frame, 0])
  plotting.plot_merge(aug_input_data[frame], aug_output_data[frame], title='', ax=axes[frame, 1])
  axes[frame, 2].imshow(label2rgb(aug_labels[frame], bg_label=0))
  axes[frame, 2].axis('off')
  
axes[0, 0].set_title('Original', size=title_size)
axes[0, 1].set_title('Augmented output', size=title_size)
axes[0, 2].set_title('Augmented labels', size=title_size)
fig.subplots_adjust(hspace=0.05, wspace=0)
# Out:
#   0%|                                                                                                                                 | 0/4 [00:00<?, ?it/s]C:\Users\snrodrig\Documents\GitHub\MitoSplit-Net\mitosplit-net\preprocessing.py:102: UserWarning: Only one label was provided to `remove_small_objects`. Did you mean to use a boolean array?
#   labels = morphology.remove_small_objects(labels, 9) #Remove too small objects
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 42.97it/s]

# %%
base_dir = 'H:/Santi/'
data_path = base_dir+'Data/' 

with gpu:
  #Inputs
  data = util.load_h5(data_path, 'Mito')
  util.save_h5(data, data_path, 'test')
  del data
# Out:
# Loading H:/Santi/Data/Mito.h5
# Converting to array

# %% [markdown]
# ### Generate augmented dataset

# %%
base_dir = 'H:/Santi/'
data_path = base_dir+'Data/' 

#Inputs
input_data = util.load_h5(data_path, 'Mito')
print('Inputs'+':', input_data.shape)

optimal_sigma = util.load_pkl(data_path, 'optimal_sigma')
threshold = util.load_pkl(data_path, 'mean_intensity_threshold')
# Out:
# Loading H:/Santi/Data/Mito.h5
# Converting to array
# Inputs: (37000, 128, 128)
#
# Loading H:/Santi/Data/optimal_sigma
#
# Loading H:/Santi/Data/mean_intensity_threshold

# %%
model_path = base_dir + 'Models/'
folder_name = util.get_filename(model_path, 'wp')
folder_name = [model_name for model_name in folder_name if 'mp' not in model_name] 

for s, t in zip(optimal_sigma[1:], threshold[1:]):
  #Outputs
  output_data = util.load_h5(data_path, 'WatProc_s%.1f_t%.1f'%(s, t))
  print('Outputs:', output_data.shape)

  #Labels
  labels = util.load_h5(data_path, 'proc_labels_s%.1f_t%.1f'%(s, t))
  print('Outputs:', labels.shape)

  #Augment
  aug_input_data, aug_output_data, aug_labels = augmentation.augStack(input_data, output_data, labels, transform, noise_transform, sigma=s)

  util.save_h5(aug_input_data, data_path, 'aug_Mito_s%.1f_t%.1f'%(s, t))
  util.save_h5(aug_output_data, data_path, 'aug_WatProc_s%.1f_t%.1f'%(s, t))
  util.save_h5(aug_labels, data_path, 'aug_labels_s%.1f_t%.1f'%(s, t))
  
  del output_data, labels, aug_input_data, aug_output_data, aug_labels
# Out:
# Loading H:/Santi/Data/WatProc_s2.1_t11.3.h5
# Converting to array
# Outputs: (37000, 128, 128)
#
# Loading H:/Santi/Data/proc_labels_s2.1_t11.3.h5
# Converting to array
# Outputs: (37000, 128, 128)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37000/37000 [11:12<00:00, 55.03it/s]
# Saving H:/Santi/Data/aug_Mito_s2.1_t11.3.h5
# Done.
#
# Saving H:/Santi/Data/aug_WatProc_s2.1_t11.3.h5
# Done.
#
# Saving H:/Santi/Data/aug_labels_s2.1_t11.3.h5
# Done.
#
# Loading H:/Santi/Data/WatProc_s2.2_t16.0.h5
# Converting to array
# Outputs: (37000, 128, 128)
#
# Loading H:/Santi/Data/proc_labels_s2.2_t16.0.h5
# Converting to array
# Outputs: (37000, 128, 128)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37000/37000 [10:57<00:00, 56.30it/s]
# Saving H:/Santi/Data/aug_Mito_s2.2_t16.0.h5
# Done.
#
# Saving H:/Santi/Data/aug_WatProc_s2.2_t16.0.h5
# Done.
#
# Saving H:/Santi/Data/aug_labels_s2.2_t16.0.h5
# Done.
#
# Loading H:/Santi/Data/WatProc_s2.2_t19.1.h5
# Converting to array
# Outputs: (37000, 128, 128)
#
# Loading H:/Santi/Data/proc_labels_s2.2_t19.1.h5
# Converting to array
# Outputs: (37000, 128, 128)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37000/37000 [10:47<00:00, 57.13it/s]
# Saving H:/Santi/Data/aug_Mito_s2.2_t19.1.h5
# Done.
#
# Saving H:/Santi/Data/aug_WatProc_s2.2_t19.1.h5
# Done.
#
# Saving H:/Santi/Data/aug_labels_s2.2_t19.1.h5
# Done.
#
# Loading H:/Santi/Data/WatProc_s2.2_t22.2.h5
# Converting to array
# Outputs: (37000, 128, 128)
#
# Loading H:/Santi/Data/proc_labels_s2.2_t22.2.h5
# Converting to array
# Outputs: (37000, 128, 128)
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 37000/37000 [10:44<00:00, 57.39it/s]
# Saving H:/Santi/Data/aug_Mito_s2.2_t22.2.h5
# Done.
#
# Saving H:/Santi/Data/aug_WatProc_s2.2_t22.2.h5
# Done.
#
# Saving H:/Santi/Data/aug_labels_s2.2_t22.2.h5
# Done.
